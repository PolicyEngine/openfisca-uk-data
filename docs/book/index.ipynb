# %% [markdown]
# # Validation
#
# Each version of `openfisca-uk-data` is checked against UKMOD input data to ensure consistency of variables where comparable.

# %% [markdown]
# ## Quantiles

# %%
from openfisca_uk_data.tests.frs.test_against_ukmod import (
    test_quantile,
    test_aggregate,
    test_average_error_among_nonzero,
    test_ukmod_nonzero_agreement,
    test_nonzero_count,
    metadata,
)
import pandas as pd
import numpy as np
from itertools import product

quantiles = [
    (variable, quantile, *test_quantile(variable, quantile))
    for variable, quantile in product(
        metadata.keys(), np.linspace(0.1, 0.9, 9).round(1)
    )
]
df = pd.DataFrame(
    quantiles, columns=("Variable", "Quantile", "OpenFisca-UK-Data", "UKMOD")
).set_index("Variable")
df["Abs. Error"] = ((df["OpenFisca-UK-Data"] - df["UKMOD"]).abs() * 100).round(
    1
)
df["Rel. Error (%)"] = (
    (df["OpenFisca-UK-Data"] / df["UKMOD"] - 1).abs() * 100
).round(1)
df["OpenFisca-UK-Data"] = df["OpenFisca-UK-Data"].round(1)
df["UKMOD"] = df["UKMOD"].round(1)
df = df.fillna(0)
df
# Out:
#                          Quantile  OpenFisca-UK-Data   UKMOD  Abs. Error  \
# Variable
# age                           0.1                9.0     9.0         0.0
# age                           0.2               18.0    18.0         0.0
# age                           0.3               25.0    25.0         0.0
# age                           0.4               32.0    32.0         0.0
# age                           0.5               40.0    40.0         0.0
# ...                           ...                ...     ...         ...
# housing_service_charges       0.5              359.0   359.0         0.4
# housing_service_charges       0.6              748.0   747.9         0.5
# housing_service_charges       0.7             1196.7  1196.7         0.2
# housing_service_charges       0.8             1695.3  1695.3         0.3
# housing_service_charges       0.9             2399.0  2393.4       562.5
#
#                          Rel. Error (%)
# Variable
# age                                 0.0
# age                                 0.0
# age                                 0.0
# age                                 0.0
# age                                 0.0
# ...                                 ...
# housing_service_charges             0.0
# housing_service_charges             0.0
# housing_service_charges             0.0
# housing_service_charges             0.0
# housing_service_charges             0.2
#
# [387 rows x 5 columns]

# %% [markdown]
# ## Aggregates

# %%
aggregates = [
    (variable, *test_aggregate(variable)) for variable in metadata.keys()
]
df = pd.DataFrame(
    aggregates, columns=("Variable", "OpenFisca-UK-Data (£bn)", "UKMOD (£bn)")
).set_index("Variable")
df["Abs. Error (£bn)"] = (
    (df["OpenFisca-UK-Data (£bn)"] - df["UKMOD (£bn)"]).abs() / 1e9
).round(1)
df["Rel. Error (%)"] = (
    (df["OpenFisca-UK-Data (£bn)"] / df["UKMOD (£bn)"] - 1).abs() * 100
).round(1)
df["OpenFisca-UK-Data (£bn)"] = (df["OpenFisca-UK-Data (£bn)"] / 1e9).round(1)
df["UKMOD (£bn)"] = (df["UKMOD (£bn)"] / 1e9).round(1)
df = df.fillna(0)
df
# Out:
#                                 OpenFisca-UK-Data (£bn)  UKMOD (£bn)  \
# Variable
# age                                                 2.6          2.6
# employment_income                                 785.1        785.1
# self_employment_income                            115.9        115.9
# tax_free_savings_income                             3.3          3.3
# capital_income                                     17.1         17.2
# property_income                                    12.7         12.6
# maintenance_income                                  2.4          2.4
# miscellaneous_income                                3.2          3.2
# private_transfer_income                             8.8          8.9
# lump_sum_income                                     5.0          5.0
# child_benefit_reported                             10.5         10.5
# housing_benefit_reported                           16.3         16.6
# AA_reported                                         3.1          3.1
# DLA_SC_reported                                     4.2          4.1
# DLA_M_reported                                      2.7          2.7
# IIDB_reported                                       0.4          0.4
# carers_allowance_reported                           2.5          2.5
# SDA_reported                                        0.0          0.0
# AFCS_reported                                       0.2          0.2
# BSP_reported                                        0.7          0.7
# maternity_allowance_reported                        0.2          0.2
# pension_credit_reported                             3.1          3.1
# child_tax_credit_reported                          13.1         13.1
# working_tax_credit_reported                         3.2          3.2
# winter_fuel_allowance_reported                      2.0          2.0
# incapacity_benefit_reported                         0.1          0.1
# universal_credit_reported                           5.4          5.4
# PIP_M_reported                                      2.6          2.6
# PIP_DL_reported                                     5.5          5.5
# SSP_reported                                        0.3          0.3
# student_loans                                      11.9         11.9
# student_payments                                    2.7          2.7
# council_tax_benefit_reported                        3.2          3.2
# council_tax                                        36.2         36.3
# maintenance_expenses                                2.2          2.2
# childcare_expenses                                  7.6          7.6
# housing_costs                                     116.7        116.7
# rent                                               73.8         73.8
# mortgage_interest_repayment                        25.8         25.8
# mortgage_capital_repayment                         63.8         63.8
# private_pension_contributions                       5.0          5.1
# water_and_sewerage_charges                         10.7         10.9
# housing_service_charges                             2.3          2.3
#
#                                 Abs. Error (£bn)  Rel. Error (%)
# Variable
# age                                          0.0             0.0
# employment_income                            0.0             0.0
# self_employment_income                       0.0             0.0
# tax_free_savings_income                      0.0             0.2
# capital_income                               0.1             0.6
# property_income                              0.2             1.3
# maintenance_income                           0.0             0.0
# miscellaneous_income                         0.0             0.0
# private_transfer_income                      0.1             0.9
# lump_sum_income                              0.0             0.0
# child_benefit_reported                       0.0             0.0
# housing_benefit_reported                     0.3             2.0
# AA_reported                                  0.0             0.0
# DLA_SC_reported                              0.0             1.0
# DLA_M_reported                               0.0             0.6
# IIDB_reported                                0.0             1.3
# carers_allowance_reported                    0.0             0.3
# SDA_reported                                 0.0             0.0
# AFCS_reported                                0.0             0.0
# BSP_reported                                 0.0             0.0
# maternity_allowance_reported                 0.0             0.7
# pension_credit_reported                      0.0             0.7
# child_tax_credit_reported                    0.0             0.0
# working_tax_credit_reported                  0.0             0.0
# winter_fuel_allowance_reported               0.0             0.0
# incapacity_benefit_reported                  0.0             0.0
# universal_credit_reported                    0.0             0.0
# PIP_M_reported                               0.0             0.0
# PIP_DL_reported                              0.0             0.0
# SSP_reported                                 0.0             1.6
# student_loans                                0.0             0.0
# student_payments                             0.0             0.0
# council_tax_benefit_reported                 0.0             0.0
# council_tax                                  0.1             0.3
# maintenance_expenses                         0.0             0.0
# childcare_expenses                           0.0             0.0
# housing_costs                                0.0             0.0
# rent                                         0.0             0.0
# mortgage_interest_repayment                  0.0             0.0
# mortgage_capital_repayment                   0.0             0.0
# private_pension_contributions                0.1             2.7
# water_and_sewerage_charges                   0.2             1.6
# housing_service_charges                      0.0             0.4

# %% [markdown]
# ## Non-zero counts
#
# Figures given in millions.

# %%
aggregates = [
    (
        variable,
        *test_nonzero_count(variable),
        test_ukmod_nonzero_agreement(variable),
    )
    for variable in metadata.keys()
]
df = pd.DataFrame(
    aggregates,
    columns=(
        "Variable",
        "OpenFisca-UK-Data (m)",
        "UKMOD (m)",
        "Non-zero agreement",
    ),
).set_index("Variable")
df["Non-zero agreement"] = (100 - df["Non-zero agreement"] * 100).round(1)
df["Abs. Error (m)"] = (
    (df["OpenFisca-UK-Data (m)"] - df["UKMOD (m)"]).abs() / 1e6
).round(1)
df["Rel. Error (%)"] = (
    (df["OpenFisca-UK-Data (m)"] / df["UKMOD (m)"] - 1).abs() * 100
).round(1)
df["OpenFisca-UK-Data (m)"] = (df["OpenFisca-UK-Data (m)"] / 1e6).round(1)
df["UKMOD (m)"] = (df["UKMOD (m)"] / 1e6).round(1)
df = df.fillna(0)
df
# Out:
#                                 OpenFisca-UK-Data (m)  UKMOD (m)  \
# Variable
# age                                              64.7       64.7
# employment_income                                26.7       26.7
# self_employment_income                            4.2        4.2
# tax_free_savings_income                           9.1        9.1
# capital_income                                   21.8       21.9
# property_income                                   2.1        2.0
# maintenance_income                                0.7        0.7
# miscellaneous_income                              0.9        0.9
# private_transfer_income                           1.2        1.3
# lump_sum_income                                   0.2        0.2
# child_benefit_reported                            6.4        6.4
# housing_benefit_reported                          3.6        3.6
# AA_reported                                       0.8        0.8
# DLA_SC_reported                                   1.3        1.3
# DLA_M_reported                                    1.1        1.1
# IIDB_reported                                     0.2        0.2
# carers_allowance_reported                         0.7        0.7
# SDA_reported                                      0.0        0.0
# AFCS_reported                                     0.1        0.1
# BSP_reported                                      0.1        0.1
# maternity_allowance_reported                      0.0        0.0
# pension_credit_reported                           1.1        1.1
# child_tax_credit_reported                         2.5        2.5
# working_tax_credit_reported                       1.3        1.3
# winter_fuel_allowance_reported                   11.7       12.1
# incapacity_benefit_reported                       0.0        0.0
# universal_credit_reported                         0.7        0.7
# PIP_M_reported                                    1.1        1.1
# PIP_DL_reported                                   1.5        1.5
# SSP_reported                                      0.1        0.1
# student_loans                                     1.3        1.3
# student_payments                                  0.6        0.6
# council_tax_benefit_reported                      4.0        4.0
# council_tax                                      26.8       26.8
# maintenance_expenses                              0.7        0.7
# childcare_expenses                                2.4        2.4
# housing_costs                                    27.7       27.7
# rent                                             10.0       10.0
# mortgage_interest_repayment                       7.8        7.8
# mortgage_capital_repayment                        7.9        7.9
# private_pension_contributions                     2.0        2.0
# water_and_sewerage_charges                       25.8       26.6
# housing_service_charges                           2.5        2.5
#
#                                 Non-zero agreement  Abs. Error (m)  \
# Variable
# age                                          100.0             0.0
# employment_income                            100.0             0.0
# self_employment_income                        99.8             0.0
# tax_free_savings_income                      100.0             0.0
# capital_income                                99.9             0.0
# property_income                              100.0             0.1
# maintenance_income                           100.0             0.0
# miscellaneous_income                         100.0             0.0
# private_transfer_income                       99.9             0.0
# lump_sum_income                              100.0             0.0
# child_benefit_reported                       100.0             0.0
# housing_benefit_reported                      99.6             0.1
# AA_reported                                  100.0             0.0
# DLA_SC_reported                              100.0             0.0
# DLA_M_reported                               100.0             0.0
# IIDB_reported                                100.0             0.0
# carers_allowance_reported                    100.0             0.0
# SDA_reported                                 100.0             0.0
# AFCS_reported                                100.0             0.0
# BSP_reported                                 100.0             0.0
# maternity_allowance_reported                 100.0             0.0
# pension_credit_reported                      100.0             0.0
# child_tax_credit_reported                    100.0             0.0
# working_tax_credit_reported                  100.0             0.0
# winter_fuel_allowance_reported               100.0             0.3
# incapacity_benefit_reported                  100.0             0.0
# universal_credit_reported                    100.0             0.0
# PIP_M_reported                               100.0             0.0
# PIP_DL_reported                              100.0             0.0
# SSP_reported                                 100.0             0.0
# student_loans                                100.0             0.0
# student_payments                             100.0             0.0
# council_tax_benefit_reported                 100.0             0.0
# council_tax                                   99.8             0.1
# maintenance_expenses                         100.0             0.0
# childcare_expenses                           100.0             0.0
# housing_costs                                100.0             0.0
# rent                                         100.0             0.0
# mortgage_interest_repayment                  100.0             0.0
# mortgage_capital_repayment                   100.0             0.0
# private_pension_contributions                100.0             0.0
# water_and_sewerage_charges                    95.3             0.8
# housing_service_charges                      100.0             0.0
#
#                                 Rel. Error (%)
# Variable
# age                                        0.0
# employment_income                          0.0
# self_employment_income                     0.0
# tax_free_savings_income                    0.1
# capital_income                             0.2
# property_income                            2.7
# maintenance_income                         0.4
# miscellaneous_income                       0.0
# private_transfer_income                    1.6
# lump_sum_income                            0.0
# child_benefit_reported                     0.0
# housing_benefit_reported                   1.4
# AA_reported                                0.0
# DLA_SC_reported                            0.0
# DLA_M_reported                             0.0
# IIDB_reported                              0.0
# carers_allowance_reported                  0.0
# SDA_reported                               0.0
# AFCS_reported                              0.0
# BSP_reported                               0.0
# maternity_allowance_reported               0.0
# pension_credit_reported                    0.3
# child_tax_credit_reported                  0.0
# working_tax_credit_reported                0.0
# winter_fuel_allowance_reported             2.7
# incapacity_benefit_reported                0.0
# universal_credit_reported                  0.1
# PIP_M_reported                             0.0
# PIP_DL_reported                            0.0
# SSP_reported                               0.0
# student_loans                              0.0
# student_payments                           0.0
# council_tax_benefit_reported               0.0
# council_tax                                0.2
# maintenance_expenses                       0.0
# childcare_expenses                         0.0
# housing_costs                              0.0
# rent                                       0.0
# mortgage_interest_repayment                0.0
# mortgage_capital_repayment                 0.0
# private_pension_contributions              0.0
# water_and_sewerage_charges                 3.1
# housing_service_charges                    0.0

# %% [markdown]
# ## Average errors
#
# Mean relative error among households which have a non-zero value in UKMOD.

# %%
aggregates = [
    (variable, test_average_error_among_nonzero(variable))
    for variable in metadata.keys()
]
df = pd.DataFrame(
    aggregates, columns=("Variable", "Mean Rel. Error (%)")
).set_index("Variable")
df["Mean Rel. Error (%)"] = (df["Mean Rel. Error (%)"] * 100).round(1)
df = df.fillna(0)
df
# Out:
#                                 Mean Rel. Error (%)
# Variable
# age                                             0.0
# employment_income                               0.0
# self_employment_income                          0.0
# tax_free_savings_income                         0.1
# capital_income                                  0.8
# property_income                                 0.9
# maintenance_income                              0.0
# miscellaneous_income                            0.0
# private_transfer_income                         3.1
# lump_sum_income                                 0.0
# child_benefit_reported                          0.0
# housing_benefit_reported                        2.6
# AA_reported                                     0.0
# DLA_SC_reported                                 0.7
# DLA_M_reported                                  0.9
# IIDB_reported                                   0.4
# carers_allowance_reported                       0.1
# SDA_reported                                    0.0
# AFCS_reported                                   0.0
# BSP_reported                                    0.0
# maternity_allowance_reported                    0.7
# pension_credit_reported                         0.2
# child_tax_credit_reported                       0.0
# working_tax_credit_reported                     0.0
# winter_fuel_allowance_reported                  0.0
# incapacity_benefit_reported                     0.0
# universal_credit_reported                       0.0
# PIP_M_reported                                  0.0
# PIP_DL_reported                                 0.0
# SSP_reported                                    3.9
# student_loans                                   0.0
# student_payments                                0.0
# council_tax_benefit_reported                    0.0
# council_tax                                     3.0
# maintenance_expenses                            0.0
# childcare_expenses                              0.0
# housing_costs                                   0.0
# rent                                            0.0
# mortgage_interest_repayment                     0.0
# mortgage_capital_repayment                      0.0
# private_pension_contributions                   0.5
# water_and_sewerage_charges                      0.0
# housing_service_charges                         0.8
